# %%
# Equal or not
a = input("Enter the first number: ")
b = input("Enter the second number: ")
if a == b:
  print ("Both inputs are equal")
else:
  print ("Your input is not equal.")
# Out:
# Enter the first number: 13
# Enter the second number: 14
# Your input is not equal.

# %%
# all are equal & any two are equal
print ("Enter first number")
first = input()
print ("Enter second number")
second = input()
print ("Enter third number")
third = input()
all = first == second and second == third and third == first
print ("All are equal:",all)
any = first == second or second == third or third == first
print ("Any of two are equal:",any)
# Out:
# Enter first number
# 12
# Enter second number
# 16
# Enter third number
# 12
# All are equal: False
# Any of two are equal: True

# %%
# marks greater or not greater than 35
a = int(input("enter value: "))
if a>=35:
    print(a,"Pass")
else:
    print(a,"Fail")
# Out:
# enter value: 66
# 66 Pass

# %%
# Max of three numbers
def max(a,b,c):
    if a>b and a>c:
        print ("maximum is :",a)
    elif b>a and b>c:
        print ("maximum is :",b)
    else:
        print ("maximum is :",c )
numbers=max(5,8,2)
# Out:
# maximum is : 8
